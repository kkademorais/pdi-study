# %% [markdown]
# <a href="https://colab.research.google.com/github/kkademorais/pdi-study/blob/main/Lab00_PDI_OpenCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread('vasco.png', cv2.IMREAD_COLOR)

plt.subplot(1,2,1)

plt.imshow(img)

img2 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.subplot(1,2,2)

plt.imshow(img2)
